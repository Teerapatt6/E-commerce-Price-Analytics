# %%
import os
import psycopg2
import pandas as pd
from dotenv import load_dotenv
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

DATABASE_URL = "postgresql://samsungs24_user:WxiB5X0zPveSKnzwTwHUaVuYDLDY4AuZ@dpg-d4gdt1idbo4c73e7niog-a.oregon-postgres.render.com/samsungs24"

conn = psycopg2.connect(DATABASE_URL)
cur = conn.cursor()

cur.execute("SELECT date, price_inr, price_thb FROM pricehistory ORDER BY date ASC;")
rows = cur.fetchall()

df = pd.DataFrame(rows, columns=["date", "price_inr", "price_thb"])

cur.close()
conn.close()

df.head()
# Out:
#                   date price_inr price_thb
# 0  2024-01-18 00:00:00   79999.0  35199.56
# 1  2024-01-19 00:00:00   79999.0  35199.56
# 2  2024-01-20 00:00:00   79999.0  35199.56
# 3  2024-01-21 00:00:00   79999.0  35199.56
# 4  2024-01-22 00:00:00   79999.0  35199.56

# %%
print('Total number of days present in the dataset: ',df.shape[0])
print('Total number of fields present in the dataset: ',df.shape[1])
# Out:
# Total number of days present in the dataset:  675
# Total number of fields present in the dataset:  3

# %%
df.describe()
# Out:
#                        date price_inr price_thb
# count                   675       675       675
# unique                  675       205       205
# top     2025-11-22 00:00:00   79999.0  35199.56
# freq                      1       189       189

# %%
data = df['price_inr'].values.reshape(-1,1)

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

pct_change = pd.Series(data_scaled.flatten()).pct_change().abs().fillna(0)
threshold = 0.1

data_scaled_filled = data_scaled.flatten().copy()

for i in range(1, len(data_scaled_filled)):
    if pct_change[i] > threshold:
        data_scaled_filled[i] = data_scaled_filled[i-1]

data_scaled_filled = data_scaled_filled.reshape(-1,1)

plt.figure(figsize=(14,6))
plt.plot(data_scaled, label='Original Data', color='gray', alpha=0.5)
plt.plot(data_scaled_filled, label=f'Cleaned Data (threshold={threshold})', color='red')
plt.title("Data Cleaning with Forward Fill")
plt.xlabel("Time Index")
plt.ylabel("Normalized Price")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

print("Original data length:", len(data_scaled))
print("Cleaned data length:", len(data_scaled_filled))
# Out:
# Original data length: 675
# Cleaned data length: 675

# %%
def create_sequences(data, seq_length, horizon=1):
    X, y = [], []
    for i in range(len(data) - seq_length - horizon + 1):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length+horizon-1])
    return np.array(X), np.array(y)

seq_length = 10
horizon = 1
X, y = create_sequences(data_scaled, seq_length, horizon)

# %%
train_ratio = 0.6
val_ratio = 0.15
test_ratio = 0.25

total_len = len(X)
train_end = int(total_len * train_ratio)
val_end = int(total_len * (train_ratio + val_ratio))

X_train, X_val, X_test = X[:train_end], X[train_end:val_end], X[val_end:]
y_train, y_val, y_test = y[:train_end], y[train_end:val_end], y[val_end:]

# %%
alpha = 0.8

last_prices_train = pd.Series(X_train[:, -1, 0])
smoothed_train = last_prices_train.ewm(alpha=alpha, adjust=False).mean()

X_train_clean = X_train.copy()
X_train_clean[:, -1, 0] = smoothed_train.values
y_train_clean = smoothed_train.values.copy()

print("X_train_clean shape:", X_train_clean.shape)
print("y_train_clean shape:", y_train_clean.shape)
# Out:
# X_train_clean shape: (399, 10, 1)
# y_train_clean shape: (399,)

# %%
train_dates = df['date'][:len(last_prices_train)]

train_dates_clean = train_dates

val_dates = df['date'][len(last_prices_train):len(last_prices_train) + len(X_val)]
test_dates = df['date'][len(last_prices_train) + len(X_val):
                         len(last_prices_train) + len(X_val) + len(X_test)]

plt.figure(figsize=(12,6))
plt.plot(train_dates, last_prices_train, label='Original Train', alpha=0.5)
plt.plot(train_dates_clean, smoothed_train, label='Smoothed Train (EWMA)', color='red')
plt.plot(val_dates, X_val[:, -1, 0], label='Validation', color='orange', alpha=0.7)
plt.plot(test_dates, X_test[:, -1, 0], label='Test', color='green', alpha=0.7)
plt.title("Price Before and After EWMA Smoothing (Train / Validation / Test)")
plt.xlabel("Date")
plt.ylabel("Price (Normalized)")
plt.legend()
plt.grid(True)
plt.show()

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(seq_length,1)))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(
    X_train_clean, y_train_clean,
    validation_data=(X_val, y_val),
    epochs=199,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/199
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.4444 - val_loss: 0.0027
# Epoch 2/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0204 - val_loss: 0.0178
# Epoch 3/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0124 - val_loss: 0.0037
# Epoch 4/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0101 - val_loss: 0.0074
# Epoch 5/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092 - val_loss: 0.0064
# Epoch 6/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - val_loss: 0.0052
# Epoch 7/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - val_loss: 0.0048
# Epoch 8/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059 - val_loss: 0.0039
# Epoch 9/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - val_loss: 0.0030
# Epoch 10/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - val_loss: 0.0022
# Epoch 11/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0055 - val_loss: 0.0014
# Epoch 12/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053 - val_loss: 0.0012
# Epoch 13/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 14/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - val_loss: 0.0012
# Epoch 15/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 16/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - val_loss: 9.7768e-04
# Epoch 17/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 18/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 19/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 20/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - val_loss: 8.7608e-04
# Epoch 21/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 9.2898e-04
# Epoch 22/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - val_loss: 8.7504e-04
# Epoch 23/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - val_loss: 8.9756e-04
# Epoch 24/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - val_loss: 8.9667e-04
# Epoch 25/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7039e-04 - val_loss: 8.3913e-04
# Epoch 26/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - val_loss: 8.4063e-04
# Epoch 27/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5430e-04 - val_loss: 9.3203e-04
# Epoch 28/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8784e-04 - val_loss: 8.6651e-04
# Epoch 29/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9751e-04 - val_loss: 8.9135e-04
# Epoch 30/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7142e-04 - val_loss: 8.9663e-04
# Epoch 31/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1175e-04 - val_loss: 8.4280e-04
# Epoch 32/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4084e-04 - val_loss: 8.2933e-04
# Epoch 33/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8124e-04 - val_loss: 8.6191e-04
# Epoch 34/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2272e-04 - val_loss: 8.4197e-04
# Epoch 35/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8839e-04 - val_loss: 8.7293e-04
# Epoch 36/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3947e-04 - val_loss: 8.4189e-04
# Epoch 37/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3328e-04 - val_loss: 8.6135e-04
# Epoch 38/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2810e-04 - val_loss: 8.3594e-04
# Epoch 39/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7565e-04 - val_loss: 8.5822e-04
# Epoch 40/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9585e-04 - val_loss: 8.4461e-04
# Epoch 41/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3356e-04 - val_loss: 8.8012e-04
# Epoch 42/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2830e-04 - val_loss: 8.5032e-04
# Epoch 43/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8858e-04 - val_loss: 9.0752e-04
# Epoch 44/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9836e-04 - val_loss: 8.5056e-04
# Epoch 45/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2021e-04 - val_loss: 8.8129e-04
# Epoch 46/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2727e-04 - val_loss: 9.1348e-04
# Epoch 47/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6169e-04 - val_loss: 8.9081e-04
# Epoch 48/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2828e-04 - val_loss: 8.7312e-04
# Epoch 49/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0399e-04 - val_loss: 9.0218e-04
# Epoch 50/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3795e-05 - val_loss: 9.1207e-04
# Epoch 51/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1361e-04 - val_loss: 9.0064e-04
# Epoch 52/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0404e-04 - val_loss: 8.6984e-04
# Epoch 53/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0732e-04 - val_loss: 8.8923e-04
# Epoch 54/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.
199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8176e-06 - val_loss: 9.3182e-04
# Epoch 161/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8595e-06 - val_loss: 9.2173e-04
# Epoch 162/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2341e-06 - val_loss: 9.2050e-04
# Epoch 163/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7394e-06 - val_loss: 9.2928e-04
# Epoch 164/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6433e-06 - val_loss: 9.3027e-04
# Epoch 165/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1792e-06 - val_loss: 9.3036e-04
# Epoch 166/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4617e-06 - val_loss: 9.2919e-04
# Epoch 167/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4656e-06 - val_loss: 9.3015e-04
# Epoch 168/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9411e-06 - val_loss: 9.2706e-04
# Epoch 169/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8968e-06 - val_loss: 9.2116e-04
# Epoch 170/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8381e-06 - val_loss: 9.2754e-04
# Epoch 171/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2468e-06 - val_loss: 9.2536e-04
# Epoch 172/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9398e-06 - val_loss: 9.2371e-04
# Epoch 173/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8769e-06 - val_loss: 9.2860e-04
# Epoch 174/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0591e-06 - val_loss: 9.3418e-04
# Epoch 175/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4343e-06 - val_loss: 9.2098e-04
# Epoch 176/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9280e-06 - val_loss: 9.2394e-04
# Epoch 177/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4543e-06 - val_loss: 9.2429e-04
# Epoch 178/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1076e-06 - val_loss: 9.2134e-04
# Epoch 179/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4546e-06 - val_loss: 9.2797e-04
# Epoch 180/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0067e-06 - val_loss: 9.2887e-04
# Epoch 181/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2368e-06 - val_loss: 9.1884e-04
# Epoch 182/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2564e-06 - val_loss: 9.2741e-04
# Epoch 183/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4349e-06 - val_loss: 9.2661e-04
# Epoch 184/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2432e-06 - val_loss: 9.2808e-04
# Epoch 185/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3977e-06 - val_loss: 9.2610e-04
# Epoch 186/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5313e-06 - val_loss: 9.3029e-04
# Epoch 187/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3033e-06 - val_loss: 9.2900e-04
# Epoch 188/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8440e-06 - val_loss: 9.2099e-04
# Epoch 189/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0532e-06 - val_loss: 9.2783e-04
# Epoch 190/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0035e-06 - val_loss: 9.2218e-04
# Epoch 191/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0078e-06 - val_loss: 9.2215e-04
# Epoch 192/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5422e-06 - val_loss: 9.2377e-04
# Epoch 193/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2114e-06 - val_loss: 9.2687e-04
# Epoch 194/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1863e-06 - val_loss: 9.2596e-04
# Epoch 195/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8574e-06 - val_loss: 9.1844e-04
# Epoch 196/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5901e-06 - val_loss: 9.2800e-04
# Epoch 197/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0632e-06 - val_loss: 9.2090e-04
# Epoch 198/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8381e-06 - val_loss: 9.2829e-04
# Epoch 199/199
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5800e-06 - val_loss: 9.2609e-04

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
y_train_pred = model.predict(X_train_clean)
y_test_pred = model.predict(X_test)

def ensure_2d(arr):
    arr = np.array(arr)
    if arr.ndim == 1:
        return arr.reshape(-1, 1)
    return arr

y_train_actual = scaler.inverse_transform(ensure_2d(y_train_clean)).flatten()
y_test_actual = scaler.inverse_transform(ensure_2d(y_test)).flatten()
y_train_pred_actual = scaler.inverse_transform(ensure_2d(y_train_pred)).flatten()
y_test_pred_actual = scaler.inverse_transform(ensure_2d(y_test_pred)).flatten()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
train_rmse = np.sqrt(mean_squared_error(y_train_actual, y_train_pred_actual))
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_rmse = np.sqrt(mean_squared_error(y_test_actual, y_test_pred_actual))
test_r2 = r2_score(y_test_actual, y_test_pred_actual)

mape = np.mean(np.abs((y_test_actual - y_test_pred_actual) / np.where(y_test_actual==0, 1e-8, y_test_actual))) * 100
mae_inr = np.mean(np.abs(y_test_actual - y_test_pred_actual))
mae_thb = mae_inr * 0.44

print(f"Train RMSE: {train_rmse:.2f}, R2: {train_r2:.2f}")
print(f"Test RMSE: {test_rmse:.2f}, R2: {test_r2:.2f}")
print(f"MAPE (%): {mape:.2f}%")
print(f"MAE: {mae_inr:.2f} INR / {mae_thb:.2f} THB")
# Out:
# Train RMSE: 36.74, R2: 1.00
# Test RMSE: 1017.08, R2: 0.83
# MAPE (%): 1.19%
# MAE: 603.76 INR / 265.66 THB

# %%
print("y_test_actual min/max:", y_test_actual.min(), y_test_actual.max())
print("y_test_pred_actual min/max:", y_test_pred_actual.min(), y_test_pred_actual.max())
# Out:
# y_test_actual min/max: 46500.0 55000.0
# y_test_pred_actual min/max: 47400.363 55104.277

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test_actual, label='Actual Price')
plt.plot(y_test_pred_actual, label='Predicted Price')
plt.title("Actual vs Predicted Price (Test Data)")
plt.xlabel("Time Index")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
def predict_multi_horizon(model, last_sequence, horizons=[1,7,30]):
    """
    last_sequence: np.array, shape = (seq_length, 1)
    horizons: list of days to predict
    return: dict {horizon_day: prediction_array}
    """
    max_horizon = max(horizons)
    preds_full = []
    current_seq = last_sequence.copy()

    for _ in range(max_horizon):
        pred = model.predict(current_seq[np.newaxis,:,:], verbose=0)
        preds_full.append(pred[0,0])
        current_seq = np.vstack([current_seq[1:], pred])

    preds_dict = {}
    for h in horizons:
        preds_dict[h] = np.array(preds_full[:h])

    return preds_dict

# %%
last_seq = X_test[-1]
horizons = [1, 7, 30]
preds_scaled = predict_multi_horizon(model, last_seq, horizons)

# %%
preds_actual = {h: scaler.inverse_transform(preds_scaled[h].reshape(-1,1)).flatten() for h in horizons}

# %%
last_date = pd.to_datetime(df['date'].iloc[-1])

future_30d_actual = scaler.inverse_transform(np.array([preds_scaled[30]]).reshape(-1,1))
future_30d_dates = pd.date_range(last_date + pd.Timedelta(days=1), periods=30, freq='D')
print("Next 30 days prediction (INR):")
for date, price in zip(future_30d_dates, future_30d_actual.flatten()):
    print(f"{date.date()}: {price:.2f}")
# Out:
# Next 30 days prediction (INR):
# 2025-11-23: 50501.17
# 2025-11-24: 50725.49
# 2025-11-25: 50902.72
# 2025-11-26: 51056.81
# 2025-11-27: 51155.02
# 2025-11-28: 51243.81
# 2025-11-29: 51331.65
# 2025-11-30: 51408.05
# 2025-12-01: 51481.23
# 2025-12-02: 51549.48
# 2025-12-03: 51616.91
# 2025-12-04: 51684.88
# 2025-12-05: 51753.27
# 2025-12-06: 51821.52
# 2025-12-07: 51889.44
# 2025-12-08: 51957.22
# 2025-12-09: 52024.88
# 2025-12-10: 52092.34
# 2025-12-11: 52159.55
# 2025-12-12: 52226.51
# 2025-12-13: 52293.21
# 2025-12-14: 52359.55
# 2025-12-15: 52425.09
# 2025-12-16: 52489.52
# 2025-12-17: 52552.70
# 2025-12-18: 52614.45
# 2025-12-19: 52674.74
# 2025-12-20: 52733.71
# 2025-12-21: 52791.26
# 2025-12-22: 52847.46
