# %%
import os
import psycopg2
import pandas as pd
from dotenv import load_dotenv
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

DATABASE_URL = "postgresql://samsungs24_user:WxiB5X0zPveSKnzwTwHUaVuYDLDY4AuZ@dpg-d4gdt1idbo4c73e7niog-a.oregon-postgres.render.com/samsungs24"

conn = psycopg2.connect(DATABASE_URL)
cur = conn.cursor()

cur.execute("SELECT date, price_inr, price_thb FROM pricehistory ORDER BY date ASC;")
rows = cur.fetchall()

df = pd.DataFrame(rows, columns=["date", "price_inr", "price_thb"])

cur.close()
conn.close()

df.head()
# Out:
#                   date price_inr price_thb
# 0  2024-01-18 00:00:00   79999.0  35199.56
# 1  2024-01-19 00:00:00   79999.0  35199.56
# 2  2024-01-20 00:00:00   79999.0  35199.56
# 3  2024-01-21 00:00:00   79999.0  35199.56
# 4  2024-01-22 00:00:00   79999.0  35199.56

# %%
print('Total number of days present in the dataset: ',df.shape[0])
print('Total number of fields present in the dataset: ',df.shape[1])
# Out:
# Total number of days present in the dataset:  675
# Total number of fields present in the dataset:  3

# %%
df.describe()
# Out:
#                        date price_inr price_thb
# count                   675       675       675
# unique                  675       205       205
# top     2025-11-22 00:00:00   79999.0  35199.56
# freq                      1       189       189

# %%
data = df['price_inr'].values.reshape(-1,1)
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
def create_sequences(data, seq_length, horizon=1):
    X, y = [], []
    for i in range(len(data) - seq_length - horizon + 1):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length+horizon-1])
    return np.array(X), np.array(y)

seq_length = 10
horizon = 1
X, y = create_sequences(data_scaled, seq_length, horizon)

# %%
split = int(len(X)*0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
alpha = 0.2
last_prices_train = pd.Series(X_train[:, -1, 0])
smoothed_train = last_prices_train.ewm(alpha=alpha, adjust=False).mean()

threshold = 1
pct_change = smoothed_train.pct_change().abs().fillna(0)
keep_idx = pct_change <= threshold

X_train_clean = X_train[keep_idx.values]
y_train_clean = y_train[keep_idx.values]

print("Before cleaning:", X_train.shape)
print("After cleaning (train only):", X_train_clean.shape)
# Out:
# Before cleaning: (532, 10, 1)
# After cleaning (train only): (532, 10, 1)

# %%
plt.figure(figsize=(12,6))
plt.plot(df['date'][:len(last_prices_train)], last_prices_train, label='Original Train', alpha=0.5)
plt.plot(df['date'][:len(last_prices_train)][keep_idx.values], smoothed_train[keep_idx.values],
         label='Cleaned Train (EWMA)', color='red')

test_dates = df['date'][split+seq_length:]
plt.plot(test_dates, X_test[:, -1, 0], label='Test Data (unchanged)', color='green', alpha=0.7)

plt.title("Price Before and After Cleaning (Train Only)")
plt.xlabel("Date")
plt.ylabel("Price (Normalized)")
plt.legend()
plt.grid(False)
plt.show()

# %%
model = Sequential()
model.add(GRU(50, activation='relu', input_shape=(seq_length,1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(
    X_train_clean, y_train_clean,
    validation_data=(X_test, y_test),
    epochs=199,
    batch_size=32,
    verbose=1
)

model.save("gru_model_latest.h5")
print("Saved model as gru_model_latest.h5")
# Out:
# Epoch 1/199
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 0.5305 - val_loss: 0.0050
# Epoch 2/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2211 - val_loss: 0.0191
# Epoch 3/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0416 - val_loss: 0.0633
# Epoch 4/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0181 - val_loss: 0.0169
# Epoch 5/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0112 - val_loss: 0.0077
# Epoch 6/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066 - val_loss: 0.0018
# Epoch 7/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 8/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 9/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 10/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 11/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 12/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 13/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 14/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 0.0011
# Epoch 15/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 16/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 17/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 18/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0017
# Epoch 19/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - val_loss: 0.0014
# Epoch 20/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0011
# Epoch 21/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 22/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 23/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 24/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 25/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 26/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 0.0010
# Epoch 27/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 9.8554e-04
# Epoch 28/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 29/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - val_loss: 0.0011
# Epoch 30/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 9.5445e-04
# Epoch 31/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 32/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 33/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 34/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 35/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 0.0012
# Epoch 36/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 37/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 9.9116e-04
# Epoch 38/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0010
# Epoch 39/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 0.0012
# Epoch 40/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 9.0550e-04
# Epoch 41/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - val_loss: 9.4387e-04
# Epoch 42/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051 - val_loss: 9.3930e-04
# Epoch 43/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - val_loss: 9.7508e-04
# Epoch 44/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 45/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 8.9826e-04
# Epoch 46/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 9.1172e-04
# Epoch 47/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 48/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 49/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 0.0011
# Epoch 50/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - val_loss: 9.2455e-04
# Epoch 51/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 9.4952e-04
# Epoch 52/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - val_loss: 9.6628e-04
# Epoch 53/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 9.3883e-04
# Epoch 54/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 55/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - val_loss: 9.6960e-04
# Epoch 56/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - val_loss: 0.0010
# Epoch 57/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 8.9748e-04
# Epoch 58/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0010
# Epoch 59/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 60/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - val_loss: 9.5148e-04
# Epoch 61/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044 - val_loss: 9.8805e-04
# Epoch 62/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - val_loss: 8.9898e-04
# Epoch 63/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 9.0629e-04
# Epoch 64/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 8.7769e-04
# Epoch 65/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - val_loss: 9.7034e-04
# Epoch 66/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 8.8866e-04
# Epoch 67/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 8.9933e-04
# Epoch 68/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0036 - val_loss: 8.9647e-04
# Epoch 69/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 70/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 9.0471e-04
# Epoch 71/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - val_loss: 8.8637e-04
# Epoch 72/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 73/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 8.7001e-04
# Epoch 74/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 0.0010
# Epoch 75/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.0010
# Epoch 76/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - val_loss: 9.0884e-04
# Epoch 77/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 78/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 9.5003e-04
# Epoch 79/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 9.9405e-04
# Epoch 80/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 8.8165e-04
# Epoch 81/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 0.0011
# Epoch 82/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0010
# Epoch 83/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - val_loss: 8.5667e-04
# Epoch 84/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 9.8054e-04
# Epoch 85/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 9.4712e-04
# Epoch 86/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 8.6054e-04
# Epoch 87/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 8.6029e-04
# Epoch 88/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 9.0064e-04
# Epoch 89/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 9.9514e-04
# Epoch 90/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - val_loss: 9.7314e-04
# Epoch 91/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 0.0010
# Epoch 92/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 93/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 9.6567e-04
# Epoch 94/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 8.7678e-04
# Epoch 95/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 96/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - val_loss: 8.8766e-04
# Epoch 97/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - val_loss: 8.6756e-04
# Epoch 98/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 9.0040e-04
# Epoch 99/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 8.6163e-04
# Epoch 100/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 8.7275e-04
# Epoch 101/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 8.6589e-04
# Epoch 102/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 0.0010
# Epoch 103/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 8.7569e-04
# Epoch 104/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - val_loss: 8.6638e-04
# Epoch 105/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 9.3075e-04
# Epoch 106/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - val_loss: 0.0010
# Epoch 107/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 108/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 8.7238e-04
# Epoch 109/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - val_loss: 8.5664e-04
# Epoch 110/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 9.1981e-04
# Epoch 111/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 8.5646e-04
# Epoch 112/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - val_loss: 8.6612e-04
# Epoch 113/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 9.6059e-04
# Epoch 114/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 0.0011
# Epoch 115/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 8.7284e-04
# Epoch 116/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - val_loss: 8.5600e-04
# Epoch 117/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 118/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - val_loss: 0.0010
# Epoch 119/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - val_loss: 9.2745e-04
# Epoch 120/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 8.7434e-04
# Epoch 121/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 9.3374e-04
# Epoch 122/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 8.6846e-04
# Epoch 123/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 124/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 8.6314e-04
# Epoch 125/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 9.4703e-04
# Epoch 126/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - val_loss: 8.6936e-04
# Epoch 127/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 8.5899e-04
# Epoch 128/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - val_loss: 9.8293e-04
# Epoch 129/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - val_loss: 8.8024e-04
# Epoch 130/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 9.2214e-04
# Epoch 131/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - val_loss: 8.6584e-04
# Epoch 132/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 8.9521e-04
# Epoch 133/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 8.9787e-04
# Epoch 134/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 8.9117e-04
# Epoch 135/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 9.9695e-04
# Epoch 136/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0010
# Epoch 137/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - val_loss: 9.1445e-04
# Epoch 138/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0046 - val_loss: 8.6330e-04
# Epoch 139/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - val_loss: 9.8095e-04
# Epoch 140/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0042 - val_loss: 8.7200e-04
# Epoch 141/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 9.0438e-04
# Epoch 142/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 143/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0050 - val_loss: 9.8636e-04
# Epoch 144/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - val_loss: 8.5915e-04
# Epoch 145/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0048 - val_loss: 8.5958e-04
# Epoch 146/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 8.9542e-04
# Epoch 147/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 148/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 9.2438e-04
# Epoch 149/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 8.6379e-04
# Epoch 150/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 8.8764e-04
# Epoch 151/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - val_loss: 8.5926e-04
# Epoch 152/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 8.8340e-04
# Epoch 153/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0010
# Epoch 154/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 8.5968e-04
# Epoch 155/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - val_loss: 9.2437e-04
# Epoch 156/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - val_loss: 9.2609e-04
# Epoch 157/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - val_loss: 8.6098e-04
# Epoch 158/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - val_loss: 8.6574e-04
# Epoch 159/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 160/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 161/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 8.6288e-04
# Epoch 162/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - val_loss: 9.2333e-04
# Epoch 163/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 9.2407e-04
# Epoch 164/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 8.8235e-04
# Epoch 165/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - val_loss: 9.0115e-04
# Epoch 166/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 0.0011
# Epoch 167/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - val_loss: 8.6572e-04
# Epoch 168/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 9.4321e-04
# Epoch 169/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 8.6135e-04
# Epoch 170/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 8.9281e-04
# Epoch 171/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 9.8712e-04
# Epoch 172/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050 - val_loss: 8.7580e-04
# Epoch 173/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 174/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 9.4759e-04
# Epoch 175/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 9.2441e-04
# Epoch 176/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 177/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 9.4287e-04
# Epoch 178/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 8.7119e-04
# Epoch 179/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 8.6386e-04
# Epoch 180/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039 - val_loss: 8.6477e-04
# Epoch 181/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - val_loss: 0.0010
# Epoch 182/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 9.3725e-04
# Epoch 183/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 9.4789e-04
# Epoch 184/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 9.4333e-04
# Epoch 185/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 8.6505e-04
# Epoch 186/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - val_loss: 9.2179e-04
# Epoch 187/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 9.9922e-04
# Epoch 188/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 9.2235e-04
# Epoch 189/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - val_loss: 9.4021e-04
# Epoch 190/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038 - val_loss: 8.6433e-04
# Epoch 191/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 8.6516e-04
# Epoch 192/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 193/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - val_loss: 8.6718e-04
# Epoch 194/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 9.5064e-04
# Epoch 195/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 9.0788e-04
# Epoch 196/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - val_loss: 8.6359e-04
# Epoch 197/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 8.8930e-04
# Epoch 198/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - val_loss: 8.9938e-04
# Epoch 199/199
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - val_loss: 9.3777e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model as gru_model_latest.h5

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
y_train_pred = model.predict(X_train_clean)
y_test_pred = model.predict(X_test)

y_train_actual = scaler.inverse_transform(y_train_clean)
y_test_actual = scaler.inverse_transform(y_test)
y_train_pred_actual = scaler.inverse_transform(y_train_pred)
y_test_pred_actual = scaler.inverse_transform(y_test_pred)

train_rmse = np.sqrt(mean_squared_error(y_train_actual, y_train_pred_actual))
train_r2 = r2_score(y_train_actual, y_train_pred_actual)
test_rmse = np.sqrt(mean_squared_error(y_test_actual, y_test_pred_actual))
test_r2 = r2_score(y_test_actual, y_test_pred_actual)

print(f"Train RMSE: {train_rmse:.2f}, R2: {train_r2:.2f}")
print(f"Test RMSE: {test_rmse:.2f}, R2: {test_r2:.2f}")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Train RMSE: 2070.01, R2: 0.96
# Test RMSE: 1025.84, R2: 0.85

# %%
mape = np.mean(np.abs((y_test_actual - y_test_pred_actual) / y_test_actual)) * 100
mae_inr = np.mean(np.abs(y_test_actual - y_test_pred_actual))
mae_thb = mae_inr * 0.44

print(f"MAPE (%): {mape:.2f}%")
print(f"MAE: {mae_inr:.2f} INR / {mae_thb:.2f} THB")
# Out:
# MAPE (%): 1.27%
# MAE: 643.71 INR / 283.23 THB

# %%
plt.figure(figsize=(12,5))
plt.plot(y_test_actual, label='Actual Price')
plt.plot(y_test_pred_actual, label='Predicted Price')
plt.title("Actual vs Predicted Price (Test Data)")
plt.xlabel("Time Index")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
def predict_multi_horizon(model, last_sequence, horizons=[1,7,30]):
    """
    last_sequence: np.array, shape = (seq_length, 1)
    horizons: list of days to predict
    return: dict {horizon_day: prediction_array}
    """
    max_horizon = max(horizons)
    preds_full = []
    current_seq = last_sequence.copy()

    for _ in range(max_horizon):
        pred = model.predict(current_seq[np.newaxis,:,:], verbose=0)
        preds_full.append(pred[0,0])
        current_seq = np.vstack([current_seq[1:], pred])

    preds_dict = {}
    for h in horizons:
        preds_dict[h] = np.array(preds_full[:h])

    return preds_dict

# %%
last_seq = X_test[-1]
horizons = [1, 7, 30]
preds_scaled = predict_multi_horizon(model, last_seq, horizons)

# %%
preds_actual = {h: scaler.inverse_transform(preds_scaled[h].reshape(-1,1)).flatten() for h in horizons}

# %%
last_date = pd.to_datetime(df['date'].iloc[-1])

future_30d_actual = scaler.inverse_transform(np.array([preds_scaled[30]]).reshape(-1,1))
future_30d_dates = pd.date_range(last_date + pd.Timedelta(days=1), periods=30, freq='D')
print("Next 30 days prediction (INR):")
for date, price in zip(future_30d_dates, future_30d_actual.flatten()):
    print(f"{date.date()}: {price:.2f}")
# Out:
# Next 30 days prediction (INR):
# 2025-11-23: 50312.32
# 2025-11-24: 50431.11
# 2025-11-25: 50564.89
# 2025-11-26: 50707.50
# 2025-11-27: 50853.31
# 2025-11-28: 51000.27
# 2025-11-29: 51147.36
# 2025-11-30: 51294.78
# 2025-12-01: 51440.64
# 2025-12-02: 51579.37
# 2025-12-03: 51714.12
# 2025-12-04: 51846.06
# 2025-12-05: 51975.45
# 2025-12-06: 52102.38
# 2025-12-07: 52226.91
# 2025-12-08: 52349.06
# 2025-12-09: 52468.89
# 2025-12-10: 52586.51
# 2025-12-11: 52702.05
# 2025-12-12: 52815.50
# 2025-12-13: 52926.89
# 2025-12-14: 53036.26
# 2025-12-15: 53143.68
# 2025-12-16: 53249.18
# 2025-12-17: 53352.80
# 2025-12-18: 53454.59
# 2025-12-19: 53554.59
# 2025-12-20: 53652.84
# 2025-12-21: 53749.38
# 2025-12-22: 53844.25
